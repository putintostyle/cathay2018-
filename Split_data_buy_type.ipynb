# %%
import pandas as pd
import numpy as np

# %%
path = "/home/math/putintostyle/cathay2018/cathay2018/process_data/split_data/"

# %%
train_info = pd.read_csv(path+"train_data_split_occupation.csv")
# train_info = train_info.drop(["Unnamed: 0"], axis = 1)
train_info.head()
# Out:
#    CUST_ID BUY_TYPE AGE SEX    HEIGHT    WEIGHT OCCUPATION  CHILD_NUM  \
# 0        1        e   h   a  0.379047  0.163892        t28          2
# 1       31        e   q   a  0.290444  0.303906        t28          0
# 2       49        c   k   a  0.290444  0.070550        t28          0
# 3       55        e   l   a  0.231375  0.023878        i37          3
# 4       62        d   e   a  0.438115 -0.069464        i37          0
#
#    BUY_MONTH BUY_YEAR    ...    INTEREST8  INTEREST9 INTEREST10 IS_APP  \
# 0          6        T    ...          NaN        NaN        NaN      a
# 1         11        T    ...          NaN        NaN        NaN      a
# 2          8        T    ...          NaN        NaN        NaN      a
# 3          8        T    ...          NaN        NaN        NaN      a
# 4          4        T    ...          NaN        NaN        NaN      a
#
#   IS_SPECIALMEMBER PARENTS_DEAD REAL_ESTATE_HAVE IS_MAJOR_INCOME MAJOR_CAT  \
# ...

# %%
buy_type = ['a','b','c','d','e','f','g']

# %%
for btype in buy_type:
    df = train_info[train_info['BUY_TYPE'] == btype]
#     print(df.head())
    print(df.shape)
    df.MINOR_CAT = df.MINOR_CAT.astype(str)
    for i in df.MINOR_CAT.values:
        if type(i) != np.double:
            print(i)
    df.to_csv('/home/math/putintostyle/cathay2018/cathay2018/process_data/split_data/train_data_buy_type_'+btype+'.csv', index=False)
# Out:
# (63141, 49)
# 32.0
# 37.0
# 28.0
# 37.0
# 28.0
# 28.0
# 37.0
# 32.0
# 38.0
# 37.0
# 32.0
# 37.0
# 37.0
# 37.0
# 28.0
# 28.0
# 37.0
# 37.0
# 32.0
# 37.0
# 32.0
# 28.0
# 28.0
# 37.0
# 28.0
# 32.0
# 28.0
# 37.0
# 32.0
# 28.0
# 28.0
# 28.0
# 28.0
# 37.0
# 32.0
# 37.0
# 28.0
# 37.0
# 32.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 28.0
# 37.0
# 28.0
# 28.0
# 37.0
# 37.0
# 37.0
# 37.0
# 28.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 32.0
# 37.0
# 37.0
# 37.0
# 32.0
# 28.0
# 32.0
# 37.0
# 37.0
# 28.0
# 28.0
# 38.0
# 28.0
# 32.0
# 28.0
# 37.0
# 7.0
# 28.0
# 37.0
# 28.0
# 37.0
# 28.0
# 37.0
# 37.0
# 47.0
# 37.0
# 37.0
# 37.0
# 32.0
# 37.0
# 37.0
# 12.0
# 28.0
# 32.0
# 37.0
# 28.0
# 37.0
# 28.0
# 28.0
# 32.0
# 37.0
# 28.0
# 28.0
# 37.0
# 28.0
# 37.0
# 28.0
# 28.0
# 37.0
# 37.0
# 37.0
# 32.0
# 28.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 37.0
# 28.0
# 41.0
# 37.0
# 28.0
# 37.0
# 37.0
# 37.0
# 37.0
# 38.0
# 37.0
# 37.0
# 37.0
# 37.0
# 29.0
# 37.0
# 28.0
# 37.0
# 32.0
# 37.0
# 28.0
# 28.0
# 32.0
# ...
